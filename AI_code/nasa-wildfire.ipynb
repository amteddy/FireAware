# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ####

# %%
import folium
import random
import time
from IPython.display import display, clear_output

# Coordinates to be marked
coordinates = [
    (63.074835, 21.551745),
    (60.414191, 22.118657),
    (68.172883, 23.728629),
    (61.103742, 28.210519),
    (62.617431, 23.700150)
]

# Create a map object with an initial location and zoom level
print("Sudden Change in WEATHER detected - Acquiring the location")
# Loop through the coordinates
for i in range(len(coordinates)):
    zoom_level = 10
    random_coord = random.choice(coordinates)
    coordinates.remove(random_coord)
    m = folium.Map(location=random_coord, zoom_start=zoom_level)
    folium.Marker(location=random_coord, popup="Random Marker").add_to(m)
    total_iterations = 100

# Create a tqdm progress bar
    progress_bar = tqdm(total=total_iterations, desc="Receiving TARGET satellite image")

# Simulate some work
    for _ in range(total_iterations):
    # Update the progress bar
        progress_bar.update(1)
    # Simulate work (replace with your actual work)
        time.sleep(0.1)

# Close the progress bar when done
    progress_bar.close()
    # Clear the previous map and display the current map
    #clear_output(wait=True)
    display(m)
    print("ANALYSING THE DAMAGE")
    progress_bar_pro = tqdm(total=total_iterations, desc="PROCESSING THE SATELLITE IMAGE")

    for _ in range(total_iterations):
    # Update the progress bar
        progress_bar_pro.update(1)
    
        time.sleep(0.1)
# Close the progress bar when done
    progress_bar_pro.close()
    
    print("NO FIRE DETECTED :)")
    
    time.sleep(50)  # Wait for a few seconds before plotting the next random coordinate

# %%
import folium
import random
import time
from tqdm import tqdm
from IPython.display import display, clear_output
total_iterations = 100
# Coordinates to be marked
coordinates = [

    (68.172883, 23.728629),

]


zoom_level = 10
random_coord = random.choice(coordinates)
print("NOTIFICATION RECEIVED FROM COMMUNITY OBSERVER")
time.sleep(3)
m = folium.Map(location=random_coord, zoom_start=zoom_level)
folium.Marker(location=random_coord, popup="Random Marker").add_to(m)
progress_bar_rec = tqdm(total=total_iterations, desc="REQUESTING TARGET satellite image")

# Simulate some work
for _ in range(total_iterations):
    # Update the progress bar
    progress_bar_rec.update(1)
    
    time.sleep(0.1)
# Close the progress bar when done
progress_bar_rec.close()
    # Clear the previous map and display the current map
#clear_output(wait=True)

display(m)

print("ANALYSING THE DAMAGE")
progress_bar_pro = tqdm(total=total_iterations, desc="PROCESSING THE SATELLITE IMAGE")

for _ in range(total_iterations):
    # Update the progress bar
    progress_bar_pro.update(1)
    
    time.sleep(0.1)
# Close the progress bar when done
progress_bar_pro.close()
from PIL import Image
import matplotlib.pyplot as plt

# Open the PNG image using PIL
image = Image.open('/kaggle/input/firewild/fire.png')

# Display the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

print("ALERT: HIGH, DAMAGE: MEDIUM, EFFECTED AREA: 4 SqKM, Wind Direction: 7 m/s SW")
# Out:
# NOTIFICATION RECEIVED FROM COMMUNITY OBSERVER
# REQUESTING TARGET satellite image: 100%|██████████| 100/100 [00:10<00:00,  9.88it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install tqdm
